# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %matplotlib inline
sns.set()
warnings.simplefilter('ignore')

# %%
data = pd.read_csv('creditcard.csv')
df = data.copy() # To keep the data as backup
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.size
# Out:
# 8829017

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.columns.to_list()
# Out:
# ['Time',
#  'V1',
#  'V2',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V10',
#  'V11',
#  'V12',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V17',
#  'V18',
#  'V19',
#  'V20',
#  'V21',
#  'V22',
#  'V23',
#  'V24',
#  'V25',
#  'V26',
#  'V27',
#  'V28',
#  'Amount',
#  'Class']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.759088e-12 -8.251210e-13 -9.655224e-13  8.321417e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.650335e-13  4.248462e-13 -3.054652e-13  8.777941e-14 -1.179734e-12
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ... -3.405795e-13 -5.723161e-13 -9.725925e-13  1.464150e-12
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean  -6.987098e-13 -5.617860e-13  3.332081e-12 -3.518874e-12      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Time values for the last 15 transactions in your dataset
df.Time.tail(15)
# Out:
# 284792    172774.0
# 284793    172775.0
# 284794    172777.0
# 284795    172778.0
# 284796    172780.0
# 284797    172782.0
# 284798    172782.0
# 284799    172783.0
# 284800    172784.0
# 284801    172785.0
# 284802    172786.0
# 284803    172787.0
# 284804    172788.0
# 284805    172788.0
# 284806    172792.0
# Name: Time, dtype: float64

# %% [markdown]
# **Checking the frequency of frauds before moving forward**

# %%
df.Class.value_counts()
# 0 → Legitimate transaction (non-fraud)
# 1 → Fraudulent transaction (fraud)
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df['Class'].value_counts('Nor')*100
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %% [markdown]
# **Data set is Highly Imbalanced**

# %%
sns.countplot(x=df.Class, hue=df.Class)
# By looking at the statistics, we can see that the data is highly imbalanced. Only 492 out of 284807 are fraud.
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# **Checking the distribution of amount**

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df.Amount)
# Out:
# <Axes: xlabel='Amount', ylabel='Density'>

# %% [markdown]
# **Since, it is a little difficult to see. Let's engineer a new feature of bins.**

# %%
df['Amount-Bins'] = ''

# %% [markdown]
# **Now, let's set the bins and their labels.**

# %%
def make_bins(predictor, size=50):
    '''
    Takes the predictor (a series or a dataframe of single predictor) and size of bins
    Returns bins and bin labels
    '''
    bins = np.linspace(predictor.min(), predictor.max(), num=size)

    bin_labels = []

    # Index of the final element in bins list
    bins_last_index = bins.shape[0] - 1

    for id, val in enumerate(bins):
        if id == bins_last_index:
            continue
        val_to_put = str(int(bins[id])) + ' to ' + str(int(bins[id + 1]))
        bin_labels.append(val_to_put)

    return bins, bin_labels

# %%
bins, bin_labels = make_bins(df.Amount, size=10)
# Now, adding bins in the column Amount-Bins.

# %%
df['Amount-Bins'] = pd.cut(df.Amount, bins=bins,
                           labels=bin_labels, include_lowest=True)
df['Amount-Bins'].head().to_frame()
# Out:
#   Amount-Bins
# 0   0 to 2854
# 1   0 to 2854
# 2   0 to 2854
# 3   0 to 2854
# 4   0 to 2854

# %%
df['Amount-Bins'].value_counts()
# Out:
# Amount-Bins
# 0 to 2854         284484
# 2854 to 5709         285
# 5709 to 8563          28
# 8563 to 11418          4
# 11418 to 14272         3
# 17127 to 19982         2
# 22836 to 25691         1
# 14272 to 17127         0
# 19982 to 22836         0
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15, 10))
sns.countplot(x='Amount-Bins', data=df)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, '0 to 2854'),
#   Text(1, 0, '2854 to 5709'),
#   Text(2, 0, '5709 to 8563'),
#   Text(3, 0, '8563 to 11418'),
#   Text(4, 0, '11418 to 14272'),
#   Text(5, 0, '14272 to 17127'),
#   Text(6, 0, '17127 to 19982'),
#   Text(7, 0, '19982 to 22836'),
#   Text(8, 0, '22836 to 25691')])

# %% [markdown]
# **Since, count of values of Bins other than '0 to 2854' are difficult to view. Let's not insert the first one.**

# %%
plt.figure(figsize=(15, 10))
sns.countplot(x='Amount-Bins', data=df[~(df['Amount-Bins'] == '0 to 2854')])
plt.xticks(rotation=45)
# keep rows that are NOT in "0 to 2854", so the other ranges will be visible now to us.
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, '0 to 2854'),
#   Text(1, 0, '2854 to 5709'),
#   Text(2, 0, '5709 to 8563'),
#   Text(3, 0, '8563 to 11418'),
#   Text(4, 0, '11418 to 14272'),
#   Text(5, 0, '14272 to 17127'),
#   Text(6, 0, '17127 to 19982'),
#   Text(7, 0, '19982 to 22836'),
#   Text(8, 0, '22836 to 25691')])

# %% [markdown]
# **We can see that mostly the amount is between 0 and 2854 euros.**

# %%
print(df.duplicated().sum())
# Out:
# 1081

# %%
df.drop_duplicates(inplace=True)
# Duplicates Removed

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
# 1️⃣ One-hot encode Amount-Bins
df_encoded = pd.get_dummies(data=df, columns=['Amount-Bins'])
df = df_encoded.copy()

# 2️⃣ Correlation heatmap
plt.figure(figsize=(20, 15))
sns.heatmap(df.corr(), cmap="coolwarm", annot=True)
plt.show()

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...  Class  Amount-Bins_0 to 2854  \
# 0  0.098698  0.363787  ...      0                   True
# 1  0.085102 -0.255425  ...      0                   True
# 2  0.247676 -1.514654  ...      0                   True
# 3  0.377436 -1.387024  ...      0                   True
# 4 -0.270533  0.817739  ...      0                   True
#
#    Amount-Bins_2854 to 5709  Amount-Bins_5709 to 8563  \
# 0                     False                     False
# 1                     False                     False
# 2                     False                     False
# 3                     False                     False
# 4                     False                     False
#
#    Amount-Bins_8563 to 11418  Amount-Bins_11418 to 14272  \
# 0                      False                       False
# 1                      False                       False
# 2                      False                       False
# 3                      False                       False
# 4                      False                       False
#
#    Amount-Bins_14272 to 17127  Amount-Bins_17127 to 19982  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    Amount-Bins_19982 to 22836  Amount-Bins_22836 to 25691
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
# [5 rows x 40 columns]

# %%
# !pip install imblearn
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\Nirmit\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Collecting imbalanced-learn (from imblearn)
#   Downloading imbalanced_learn-0.14.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\users\nirmit\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn->imblearn) (2.3.1)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\users\nirmit\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn->imblearn) (1.16.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\users\nirmit\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn->imblearn) (1.7.0)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\users\nirmit\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn->imblearn) (1.5.1)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\nirmit\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn->imblearn) (3.6.0)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Downloading imbalanced_learn-0.14.0-py3-none-any.whl (239 kB)
#    ---------------------------------------- 0.0/240.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/240.0 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/240.0 kB 653.6 kB/s eta 0:00:01
#    ---------------------------------------  235.5/240.0 kB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 240.0/240.0 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.14.0 imblearn-0.0

# %%
scaler = StandardScaler()

# %%
X = df.drop(labels='Class', axis=1)
Y = df['Class']

X.shape, Y.shape
# Out:
# ((283726, 39), (283726,))

# %%
X.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...  Amount  Amount-Bins_0 to 2854  \
# 0  0.098698  0.363787  ...  149.62                   True
# 1  0.085102 -0.255425  ...    2.69                   True
# 2  0.247676 -1.514654  ...  378.66                   True
# 3  0.377436 -1.387024  ...  123.50                   True
# 4 -0.270533  0.817739  ...   69.99                   True
#
#    Amount-Bins_2854 to 5709  Amount-Bins_5709 to 8563  \
# 0                     False                     False
# 1                     False                     False
# 2                     False                     False
# 3                     False                     False
# 4                     False                     False
#
#    Amount-Bins_8563 to 11418  Amount-Bins_11418 to 14272  \
# 0                      False                       False
# 1                      False                       False
# 2                      False                       False
# 3                      False                       False
# 4                      False                       False
#
#    Amount-Bins_14272 to 17127  Amount-Bins_17127 to 19982  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    Amount-Bins_19982 to 22836  Amount-Bins_22836 to 25691
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
# [5 rows x 39 columns]

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(
    X, Y, random_state=42, test_size=0.3, shuffle=True)

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (198608, 39) (198608,)
# (85118, 39) (85118,)

# %%
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[-1.71176469,  0.54418331, -0.00253127, ..., -0.0022439 ,
#          0.        , -0.0022439 ],
#        [-0.80471758,  0.43329534, -0.20433596, ..., -0.0022439 ,
#          0.        , -0.0022439 ],
#        [ 1.18142859,  0.06286558, -0.31319062, ..., -0.0022439 ,
#          0.        , -0.0022439 ],
#        ...,
#        [-0.31134476,  0.64542209, -0.02810829, ..., -0.0022439 ,
#          0.        , -0.0022439 ],
#        [-0.13124926,  1.01820088, -0.07992348, ..., -0.0022439 ,
#          0.        , -0.0022439 ],
#        [-0.38346298, -0.24298138,  0.50132   , ..., -0.0022439 ,
#          0.        , -0.0022439 ]], shape=(198608, 39))

# %%
x_train.shape , y_train.value_counts()
# Out:
# ((198608, 39),
#  Class
#  0    198269
#  1       339
#  Name: count, dtype: int64)

# %%
smote = SMOTE(random_state=42)
x_train_resampled, y_train_resampled = smote.fit_resample(x_train_scaled, y_train)

# %%
x_train_resampled.shape , y_train_resampled.value_counts()
# Out:
# ((396538, 39),
#  Class
#  0    198269
#  1    198269
#  Name: count, dtype: int64)

# %% [markdown]
# **Resampled using SMOTE to handle Imbalance**

# %% [markdown]
# ## **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression()

# %%
lr_model.fit(x_train_resampled, y_train_resampled)
# Out:
# LogisticRegression()

# %%
# Predictions on scaled training and test data
lr_pred_train = lr_model.predict(x_train_resampled)
lr_pred_test = lr_model.predict(x_test_scaled)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
# Predictions on the test set
y_pred = lr_model.predict(x_test_scaled)

# %%
# Confusion matrix values
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

# Confusion matrix DataFrame for easier readability
conf_matrix_df = pd.DataFrame(
    {
        'Predicted Fraud': [tp, fp],
        'Predicted Not Fraud': [fn, tn]
    },
    index=['Actual Fraud', 'Actual Not Fraud']
)
conf_matrix_df
# Out:
#                   Predicted Fraud  Predicted Not Fraud
# Actual Fraud                  120                   14
# Actual Not Fraud             2071                82913

# %%
print("Confusion Matrix:\n", conf_matrix_df)
print("\nClassification Report:\n", classification_report(y_test, y_pred, digits=4))
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix:
#                    Predicted Fraud  Predicted Not Fraud
# Actual Fraud                  120                   14
# Actual Not Fraud             2071                82913
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9998    0.9756    0.9876     84984
#            1     0.0548    0.8955    0.1032       134
#
#     accuracy                         0.9755     85118
#    macro avg     0.5273    0.9356    0.5454     85118
# weighted avg     0.9983    0.9755    0.9862     85118
#
# Accuracy: 0.9755045936229705

# %%
plt.figure(figsize=(6,4))
sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix Heatmap')
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Get predicted probabilities for the positive class (fraud)
y_probs = lr_model.predict_proba(x_test_scaled)[:, 1]

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_probs)

# Calculate AUC
auc_score = roc_auc_score(y_test, y_probs)
print("AUC Score:", auc_score)

# Plot ROC curve
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {auc_score:.4f})')
plt.plot([0,1], [0,1], color='red', linestyle='--')  # Random classifier line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Logistic Regression')
plt.legend()
plt.show()
# Out:
# AUC Score: 0.9785799890690575

# %% [markdown]
# ## **NAIVE BAYES**

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()

# %%
nb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
nb_pred = nb.predict(x_test)
nb_pred_proba = nb.predict_proba(x_test)[:, 1]

# %%
nb_auc = roc_auc_score(y_test, nb_pred_proba)

# %%
# Predictions & probabilities
nb_pred = nb.predict(x_test)
nb_pred_proba = nb.predict_proba(x_test)[:, 1]

# Accuracy
accuracy = accuracy_score(y_test, nb_pred)
print(f"Accuracy: {accuracy:.4f}")

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, nb_pred))

# Confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, nb_pred))
# Out:
# Accuracy: 0.9927
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     84984
#            1       0.12      0.59      0.20       134
#
#     accuracy                           0.99     85118
#    macro avg       0.56      0.79      0.60     85118
# weighted avg       1.00      0.99      1.00     85118
#
#
# Confusion Matrix:
# [[84421   563]
#  [   55    79]]

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, nb_pred_proba)

# Calculate AUC
auc_score = roc_auc_score(y_test, nb_pred_proba)
print("AUC Score:", auc_score)

# Plot ROC curve
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {auc_score:.4f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')  # Random classifier line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Naive Bayes')
plt.legend()
plt.show()
# Out:
# AUC Score: 0.9628506893659351

# %%
from sklearn.metrics import recall_score

nb_recall = recall_score(y_test, nb_pred)
print("Recall:", nb_recall)
# Out:
# Recall: 0.5895522388059702

# %% [markdown]
# **Conclusion: Naive Bayes didn't perform well as compared to the other ones.**

# %% [markdown]
# ## **DEcision TREE**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve

# %%
# Create and train the Decision Tree model
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Predict on test data
dt_pred = dt_model.predict(x_test)

# %%
# Accuracy
dt_accuracy = accuracy_score(y_test, dt_pred)
print("Decision Tree Accuracy:", dt_accuracy)
# Classification report
print("\nClassification Report:\n", classification_report(y_test, dt_pred))

# Confusion matrix
print("\nConfusion Matrix:\n", confusion_matrix(y_test, dt_pred))
# Out:
# Decision Tree Accuracy: 0.9991541154632393
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84984
#            1       0.71      0.79      0.75       134
#
#     accuracy                           1.00     85118
#    macro avg       0.85      0.90      0.87     85118
# weighted avg       1.00      1.00      1.00     85118
#
#
# Confusion Matrix:
#  [[84940    44]
#  [   28   106]]

# %%
# ROC curve and AUC
y_probs_dt = dt_model.predict_proba(x_test)[:, 1]  # Probability of positive class
fpr, tpr, thresholds = roc_curve(y_test, y_probs_dt)
auc_score = roc_auc_score(y_test, y_probs_dt)
print("AUC Score:", auc_score)

# Plot ROC curve
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {auc_score:.4f})')
plt.plot([0,1], [0,1], color='red', linestyle='--')  # Random classifier line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Decision Tree')
plt.legend()
plt.show()
# Out:
# AUC Score: 0.895263515801394

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report
import pandas as pd

# ----- Naive Bayes -----
nb = GaussianNB()
nb.fit(x_train, y_train)
nb_pred = nb.predict(x_test)
nb_pred_proba = nb.predict_proba(x_test)[:, 1]

nb_accuracy = accuracy_score(y_test, nb_pred)
nb_precision = precision_score(y_test, nb_pred)
nb_recall = recall_score(y_test, nb_pred)
nb_f1 = f1_score(y_test, nb_pred)
nb_auc = roc_auc_score(y_test, nb_pred_proba)

print("Naive Bayes Report:\n", classification_report(y_test, nb_pred))

# ----- Decision Tree -----
dt = DecisionTreeClassifier(random_state=42)
dt.fit(x_train, y_train)
dt_pred = dt.predict(x_test)
dt_pred_proba = dt.predict_proba(x_test)[:, 1]

dt_accuracy = accuracy_score(y_test, dt_pred)
dt_precision = precision_score(y_test, dt_pred)
dt_recall = recall_score(y_test, dt_pred)
dt_f1 = f1_score(y_test, dt_pred)
dt_auc = roc_auc_score(y_test, dt_pred_proba)

print("Decision Tree Report:\n", classification_report(y_test, dt_pred))

# ----- Model Comparison -----
comparison_df = pd.DataFrame({
    "Model": ["Naive Bayes", "Decision Tree"],
    "Accuracy": [nb_accuracy, dt_accuracy],
    "Precision": [nb_precision, dt_precision],
    "Recall": [nb_recall, dt_recall],
    "F1-Score": [nb_f1, dt_f1],
    "ROC-AUC": [nb_auc, dt_auc]
})

print("\nModel Comparison:\n", comparison_df)
# Out:
# Naive Bayes Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     84984
#            1       0.12      0.59      0.20       134
#
#     accuracy                           0.99     85118
#    macro avg       0.56      0.79      0.60     85118
# weighted avg       1.00      0.99      1.00     85118
#
# Decision Tree Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84984
#            1       0.71      0.79      0.75       134
#
#     accuracy                           1.00     85118
#    macro avg       0.85      0.90      0.87     85118
# weighted avg       1.00      1.00      1.00     85118
#
#
# Model Comparison:
#             Model  Accuracy  Precision    Recall  F1-Score   ROC-AUC
# 0    Naive Bayes  0.992739   0.123053  0.589552  0.203608  0.962851
# 1  Decision Tree  0.999154   0.706667  0.791045  0.746479  0.895264
